# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import numpy as np
import matplotlib.pyplot as plt
import ipaddress
from user_agents import parse
import httpagentparser

# %%
test = pd.read_csv("../../dataset/Doceree-HCP_Test.csv", encoding='latin-1')
train = pd.read_csv("../../dataset/Doceree-HCP_Train.csv",  encoding='latin-1')

# %%
test["USERPLATFORMUID"]
# Out:
# 0        0d5041ff-f0b6-4d1a-9ad7-0a29f7d485b4
# 1        c8396dd0-969f-4d99-a40b-b7bb1f516154
# 2        3c97a081-6518-43f8-9f26-369759cfb471
# 3        3e2578c8-f794-41af-a38c-c5cfb3c0f014
# 4        ec2ae7ce-6a8c-4156-98a7-07203e60f483
#                          ...
# 28488    78ce4bbe-3885-4c14-b945-a0ea1e4574f4
# 28489    a53799e1-b279-40cf-b467-11b4d659e325
# 28490    acc732a8-2ee9-4e2c-9933-70e34db48101
# 28491    dce21294-b105-4abb-b145-4e62d71def44
# 28492    f9b193b0-82b0-4ac8-b24a-5635401ca934
# Name: USERPLATFORMUID, Length: 28493, dtype: object

# %%
train.loc[train["USERPLATFORMUID"] == '3e2578c8-f794-41af-a38c-c5cfb3c0f014']
# Out:
#             ID DEVICETYPE  PLATFORM_ID    BIDREQUESTIP  \
# 204       1205    Desktop            7  71.105.120.171
# 294       1295    Desktop            7  71.105.120.171
# 443       1444    Desktop            7  71.105.120.171
# 455       1456    Desktop            7  71.105.120.171
# 536       1537    Desktop            7  71.105.120.171
# ...        ...        ...          ...             ...
# 113524  114525    Desktop            7  71.105.120.171
# 113546  114547    Desktop            7  71.105.120.171
# 113649  114650    Desktop            7  71.105.120.171
# 113776  114777    Desktop            7  71.105.120.171
# 113849  114850    Desktop            7  71.105.120.171
#
#                              USERPLATFORMUID  USERCITY  USERZIPCODE  \
# 204     3e2578c8-f794-41af-a38c-c5cfb3c0f014  Brooklyn      11226.0
# 294     3e2578c8-f794-41af-a38c-c5cfb3c0f014  Brooklyn      11226.0
# 443     3e2578c8-f794-41af-a38c-c5cfb3c0f014  Brooklyn      11226.0
# ...

# %%
for uid in test["USERPLATFORMUID"]:
    if train[train["USERPLATFORMUID"] == uid]:
        print(uid)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6488/1341525025.py in ?()
#       1 for uid in test["USERPLATFORMUID"]:
# ----> 2     if train[train["USERPLATFORMUID"] == uid]:
#       3         print(uid)
#
# ~/anaconda3/envs/atom/lib/python3.11/site-packages/pandas/core/generic.py in ?(self)
#    1525     @final
#    1526     def __nonzero__(self) -> NoReturn:
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530         )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
